# %% [markdown]
# # Capstone: Laptop prices

# %% [markdown]
# ### Task:
#
# Predict which laptop characteristics have a strong influence on the lapton price.

# %% [markdown]
# ### Context
# A dataset for 1300 laptop models.
#
# ### Content
# Company Name
# Product Name
# Laptop Type
# Screen Inches
# Screen Resolution
# CPU Model
# RAM Characteristics
# Memory
# GPU Characteristics
# Operating System
# Laptop's Weight
# Laptop's Price

# %% [markdown]
# ## 2. Dataset exploration

# %% [markdown]
# ### 2.1. Loading

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Lasso

import statsmodels.formula.api as smf

# %matplotlib inline

# %%
df=pd.read_csv("../datasets/laptops.csv", index_col=0, encoding='latin')
df.head(n=25)
# Out:
#    Company                                  Product            TypeName  \
# 1    Apple                              MacBook Pro           Ultrabook
# 2    Apple                              Macbook Air           Ultrabook
# 3       HP                                   250 G6            Notebook
# 4    Apple                              MacBook Pro           Ultrabook
# 5    Apple                              MacBook Pro           Ultrabook
# 6     Acer                                 Aspire 3            Notebook
# 7    Apple                              MacBook Pro           Ultrabook
# 8    Apple                              Macbook Air           Ultrabook
# 9     Asus                          ZenBook UX430UN           Ultrabook
# 10    Acer                                  Swift 3           Ultrabook
# 11      HP                                   250 G6            Notebook
# 12      HP                                   250 G6            Notebook
# ...

# %% [markdown]
# ### 2.2. Data cleaning and feature selection (human approach)

# %% [markdown]
# not a lot of variables, the majority - categorical. Can deduct columns for num:
# - CPU power (needs to be multiplied)
# - Total Memory capacity
# - inches,
# - resolution (? inches are dif)
# - weight
# - RAM
#
# for cat:
# - type of memory (2 of categories, yes / no), flash storage => SSD
# - type of display
# - processor type
# - videocart (? can be too much), better by producers (extract from name)
# - macos X => mac os
# - full HD yes/no
# - retina yes/no
# - touch screen yes/no
